# %%
# importando bibliotecas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://pycourse.s3.amazonaws.com/bike-sharing.csv")

# %%
df
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday
# 0      2011-01-01       1       1     0      1     0           0        6  \
# 1      2011-01-01       2       1     0      1     1           0        6
# 2      2011-01-01       3       1     0      1     2           0        6
# 3      2011-01-01       4       1     0      1     3           0        6
# 4      2011-01-01       5       1     0      1     4           0        6
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed
# ...

# %%
# a qual o tamanho desse dataset?
df.shape
# Out:
# (17379, 17)

# %%
#b qual a média ca coluna windspeed?
df['windspeed'].mean()
# Out:
# 0.19009760630646177

# %%
#c qual a média da coluna temp?
df['temp'].mean()
# Out:
# 0.4969871684216583

# %%
# quantos registros existem para o ano de 2011?
df[df['year'] == 0]
# Out:
#         datetime  rec_id  season  year  month  hour  is_holiday  weekday
# 0     2011-01-01       1       1     0      1     0           0        6  \
# 1     2011-01-01       2       1     0      1     1           0        6
# 2     2011-01-01       3       1     0      1     2           0        6
# 3     2011-01-01       4       1     0      1     3           0        6
# 4     2011-01-01       5       1     0      1     4           0        6
# ...          ...     ...     ...   ...    ...   ...         ...      ...
# 8640  2011-12-31    8641       1     0     12    19           0        6
# 8641  2011-12-31    8642       1     0     12    20           0        6
# 8642  2011-12-31    8643       1     0     12    21           0        6
# 8643  2011-12-31    8644       1     0     12    22           0        6
# 8644  2011-12-31    8645       1     0     12    23           0        6
#
#       is_workingday  weather_condition  temp   atemp  humidity  windspeed
# ...

# %%
# quantos registros existem para o ano de 2012?
df[df['year'] == 1]
# Out:
#          datetime  rec_id  season  year  month  hour  is_holiday  weekday
# 8645   2012-01-01    8646       1     1      1     0           0        0  \
# 8646   2012-01-01    8647       1     1      1     1           0        0
# 8647   2012-01-01    8648       1     1      1     2           0        0
# 8648   2012-01-01    8649       1     1      1     3           0        0
# 8649   2012-01-01    8650       1     1      1     4           0        0
# ...           ...     ...     ...   ...    ...   ...         ...      ...
# 17374  2012-12-31   17375       1     1     12    19           0        1
# 17375  2012-12-31   17376       1     1     12    20           0        1
# 17376  2012-12-31   17377       1     1     12    21           0        1
# 17377  2012-12-31   17378       1     1     12    22           0        1
# 17378  2012-12-31   17379       1     1     12    23           0        1
#
#        is_workingday  weather_condition  temp   atemp  humidity  windspeed
# ...

# %%
# quantas locações de bicicletas foram efetuadas em 2011
df[df['year'] == 0].loc[:,'total_count'].sum()
# Out:
# 1243103

# %%
# quantas locações de bicicletas foram efetuadas em 2012
df[df['year'] == 1].loc[:,'total_count'].sum()
# Out:
# 2049576

# %%
# Qual estação do ano contém a maior média de locações de bicicletas?
df.groupby(by='season')['total_count'].mean()
# Out:
# season
# 1    111.114569
# 2    208.344069
# 3    236.016237
# 4    198.868856
# Name: total_count, dtype: float64

# %%
# Qual estação do ano contém a menor média de locações de bicicletas?
df.groupby(by='season')['total_count'].mean()
# Out:
# season
# 1    111.114569
# 2    208.344069
# 3    236.016237
# 4    198.868856
# Name: total_count, dtype: float64

# %%
# Qual horário do dia contém a maior média de locações de bicicletas?
df.groupby(by='hour')['total_count'].mean()
# Out:
# hour
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 3      11.727403
# 4       6.352941
# 5      19.889819
# 6      76.044138
# 7     212.064649
# 8     359.011004
# 9     219.309491
# 10    173.668501
# 11    208.143054
# 12    253.315934
# 13    253.661180
# 14    240.949246
# 15    251.233196
# 16    311.983562
# 17    461.452055
# 18    425.510989
# 19    311.523352
# 20    226.030220
# 21    172.314560
# 22    131.335165
# 23     87.831044
# Name: total_count, dtype: float64

# %%
# Qual horário do dia contém a menor média de locações de bicicletas?
df.groupby(by='hour')['total_count'].mean()
# Out:
# hour
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 3      11.727403
# 4       6.352941
# 5      19.889819
# 6      76.044138
# 7     212.064649
# 8     359.011004
# 9     219.309491
# 10    173.668501
# 11    208.143054
# 12    253.315934
# 13    253.661180
# 14    240.949246
# 15    251.233196
# 16    311.983562
# 17    461.452055
# 18    425.510989
# 19    311.523352
# 20    226.030220
# 21    172.314560
# 22    131.335165
# 23     87.831044
# Name: total_count, dtype: float64

# %%
# que dia da semana contém a maior média de locações de bicicletas?
df.groupby(by='weekday')['total_count'].mean()
# Out:
# weekday
# 0    177.468825
# 1    183.744655
# 2    191.238891
# 3    191.130505
# 4    196.436665
# 5    196.135907
# 6    190.209793
# Name: total_count, dtype: float64

# %%
# que dia da semana contém a menor média de locações de bicicletas?
df.groupby(by='weekday')['total_count'].mean()
# Out:
# weekday
# 0    177.468825
# 1    183.744655
# 2    191.238891
# 3    191.130505
# 4    196.436665
# 5    196.135907
# 6    190.209793
# Name: total_count, dtype: float64

# %%
df.groupby(by='hour')[df['weekday']==3]['total_count'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.groupby(by='hour')[df['weekday']==3]['total_count'].mean()
#
# File c:\Users\rafael.cecyn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1773, in DataFrameGroupBy.__getitem__(self, key)
#    1766 if isinstance(key, tuple) and len(key) > 1:
#    1767     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1768     # valid syntax, so don't raise
#    1769     raise ValueError(
#    1770         "Cannot subset columns with a tuple with more than one element. "
#    1771         "Use a list instead."
#    1772     )
# -> 1773 return super().__getitem__(key)
#
# File c:\Users\rafael.cecyn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:239, in SelectionMixin.__getitem__(self, key)
# ...

# %%
df[df['weekday']==3].groupby(by='hour')['total_count'].mean()
# Out:
# hour
# 0      34.557692
# 1      15.336538
# 2       7.813725
# 3       4.888889
# 4       4.968750
# 5      25.750000
# 6     107.807692
# 7     303.980769
# 8     488.326923
# 9     238.528846
# 10    131.894231
# 11    152.201923
# 12    193.903846
# 13    185.826923
# 14    170.548077
# 15    181.288462
# 16    272.961538
# 17    513.144231
# 18    494.029126
# 19    357.504854
# 20    256.660194
# 21    194.669903
# 22    143.689320
# 23     83.737864
# Name: total_count, dtype: float64

# %%
df[df['weekday']==6].groupby(by='hour')['total_count'].mean()
# Out:
# hour
# 0      94.304762
# 1      67.780952
# 2      50.495238
# 3      22.885714
# 4       7.657143
# 5       8.291262
# 6      21.000000
# 7      45.961905
# 8     114.476190
# 9     186.790476
# 10    263.723810
# 11    328.609524
# 12    375.380952
# 13    385.371429
# 14    381.333333
# 15    382.428571
# 16    366.142857
# 17    334.409524
# 18    292.048077
# 19    239.932692
# 20    180.865385
# 21    156.000000
# 22    139.663462
# 23    115.855769
# Name: total_count, dtype: float64
